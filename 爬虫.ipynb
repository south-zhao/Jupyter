# %%
import requests

url = "https://novelebook.com/alpha-asher-by-jane-doe/r326856.html"

headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36"}
response = requests.get(url=url, headers=headers)

print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang='en'>
# <head>
# <title>Read  Alpha Asher By Jane Doe Chapter 1</title>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1">
# <meta name="google-site-verification" content="TlanpqxvMF1y8XDdvXZB251zFS7JP8DQHaKim5MrELI" />
# <meta name="propeller" content="a94992fedacc0f1e5ad327a25c428637">
# <link rel="shortcut icon" href='https://s.novelebook.com/favicon.ico'>
# <link rel="apple-touch-icon" sizes="57x57" href='https://s.novelebook.com/favicon-57x57.png'>
# <link rel="apple-touch-icon" sizes="60x60" href='https://s.novelebook.com/favicon-60x60.png'>
# <link rel="apple-touch-icon" sizes="72x72" href='https://s.novelebook.com/favicon-72x72.png'>
# <link rel="apple-touch-icon" sizes="76x76" href='https://s.novelebook.com/favicon-76x76.png'>
# <link rel="apple-touch-icon" sizes="114x114" href='https://s.novelebook.com/favicon-114x114.png'>
# <link rel="apple-touch-icon" sizes="120x120" href='https://s.novelebook.com/favicon-120x120.png'>
# <link rel="apple-touch-icon" sizes="144x144" href='https://s.novelebook.com/favicon-144x144.png'>
# <link rel="apple-touch-icon" sizes="152x152" href='https://s.novelebook.com/favicon-152x152.png'>
# <link rel="apple-touch-icon" sizes="180x180" href='https://s.novelebook.com/favicon-180x180.png'>
# <link rel="icon" type="image/png" sizes="192x192" href='https://s.novelebook.com/favicon-192x192.png'>
# <link rel="icon" type="image/png" href='https://s.novelebook.com/favicon-16x16.png' sizes="16x16">
# <link rel="icon" type="image/png" href='https://s.novelebook.com/favicon-32x32.png' sizes="32x32">
# <link rel="icon" type="image/png" href='https://s.novelebook.com/favicon-96x96.png' sizes="96x96">
# <link rel="preload" as="font" href='https://novelebook.com/assets/libs/font-awesome/fonts/fontawesome-webfont.woff2?v=4.7.0' type="font/woff2" crossorigin>
# <link rel="preload" as="font" href='https://novelebook.com/assets/fonts/RobotoCondensed-Regular.woff' type="font/woff" crossorigin>
# <meta name="title" content="Read  Alpha Asher By Jane Doe Chapter 1">
# <meta name="description" content="Read free Book  Alpha Asher By Jane Doe Chapter 1, written by Jane Doe at novelebook.com. Read  Alpha Asher By Jane Doe full novel online for free here.">
# <meta name="keywords" content=" Alpha Asher By Jane Doe Chapter 1">
# <meta property="fb:app_id" content="408227363640274" />
# <meta property="og:url" content='https://novelebook.com/alpha-asher-by-jane-doe/r326856.html'>
# <meta property="og:title" content='Read  Alpha Asher By Jane Doe Chapter 1'>
# <meta property="og:type" content="article">
# <meta property="og:image" content='https://s.novelebook.com/images/book/origin/book-1655315342.jpeg'>
# <meta property="og:description" content='Read free Book  Alpha Asher By Jane Doe Chapter 1, written by Jane Doe at novelebook.com. Read  Alpha Asher By Jane Doe full novel online for free here.'>
# <meta property="og:site_name" content='Novels online'>
# <link rel="canonical" href='https://novelebook.com/alpha-asher-by-jane-doe/r326856.html'>
# <link rel="alternate" href='https://novelebook.com/alpha-asher-by-jane-doe/r326856.html' hreflang='en' />
# <link rel="stylesheet" href='/assets/css/base.min.css?v=2.1.50&p=desktop' />
# <link rel="stylesheet" href='/assets/css/pages/book-reader.min.css?v=2.1.50&p=desktop' />
# </head>
# <body>
# <header class="header"><div class="container"><div class="row"><div class="col-lg-2 col-sm-2 col-md-2 hleft"><a class="brand" href="/"><div class="logo">Novels online</div></a></div><div class="col-lg-8 col-sm-8 col-md-8 hmid text-center"><div class="search-group"><div class="input-group"><input type="text" class="keyword form-control" name="keyword" placeholder='Enter title...' autocomplete="off" data-url='https://a.novelebook.com/v1/search'><span class="btn-search input-group-addon btn-success"><i class="fa fa-search icon-search" aria-hidden="true"></i></span></div><ul class="nav results hidden"></ul></div><ul class="nav navbar-nav navbar-center"><li><a href="/">Home</a></li><li><a href="/urban-bc22.html">Urban</a></li><li><a href="/mature-bc14.html">Mature</a></li><li><a href="/romance-bc1.html">Romance</a></li><li><a href="/sports-bc15.html">Sports</a></li><li><a href="/drama-bc18.html">Drama</a></li><li class="dropdown" onmouseover="typeof openDropdown !== 'undefined' && openDropdown(this)" onmouseout="typeof closeDropdown !== 'undefined' && closeDropdown(this)"><a class="dropdown-toggle" href="javascript:void(0);" aria-expanded="false">More <i class="fa fa-angle-double-down" aria-hidden="true"></i></a><ul class="dropdown-menu"><li><a href="/fantasy-romance-bc26.html">Fantasy Romance</a></li><li><a href="/werewolf-bc27.html">Werewolf</a></li><li><a href="/vampire-bc28.html">Vampire</a></li></ul></li></ul></div><div class="col-lg-2 col-sm-2 col-md-2 hright text-center"><div class="auth" onclick="showModal('.auth-form', 'Sign In')"><span class="avt"><i class="fa fa-user-o"></i></span><span class="info"><label class="login">Sign In</label></span></div><div class="auth-form hidden"><div class="sprite-wp"></div><div class="form text-left login-form" novalidate="novalidate"><div class="form-group text-center has-error form-error hidden"><span class="help-block"></span></div><div class="form-group"><div class="input-group"><span class="input-group-addon"><i class="fa fa-envelope"></i></span><input class="form-control" type="text" name="email" placeholder='Email' autocomplete="off"></div></div><div class="form-group"><div class="input-group"><span class="input-group-addon"><i class="fa fa-lock"></i></span><input class="form-control" type="password" name="password" placeholder='Password' autocomplete="off"></div></div><div class="form-group"><button class="btn btn-success btn-block btn-submit" type="button" onclick="login()" disabled><span class="loading hidden"><i class="fa fa-spinner fa-spin fa-fw"></i></span> Sign In</button></div><div class="form-group"><div class="register"><a href="javascript:void(0);" onclick="switchForm('register')">Register</a></div><div class="forgot-password"><a href="/auth/forgot-password">Forgot password</a></div></div></div><div class="form text-left register-form hidden" novalidate="novalidate"><div class="form-group text-center has-error form-error hidden"><span class="help-block"></span></div><div class="form-group"><div class="input-group"><span class="input-group-addon"><i class="fa fa-user"></i></span><input class="form-control" type="text" name="username" placeholder='User Name' autocomplete="off"></div></div><div class="form-group"><div class="input-group"><span class="input-group-addon"><i class="fa fa-envelope"></i></span><input class="form-control" type="text" name="email" placeholder='Email' autocomplete="off"></div></div><div class="form-group"><div class="input-group"><span class="input-group-addon"><i class="fa fa-lock"></i></span><input class="form-control" type="password" name="password" placeholder='Password' autocomplete="off"></div></div><div class="form-group"><div class="input-group"><span class="input-group-addon"><i class="fa fa-lock"></i></span><input class="form-control" type="password" name="confirm_password" placeholder='Confirm password' autocomplete="off"></div></div><div class="form-group"><button class="btn btn-success btn-block btn-submit" type="button" onclick="regis ...
# <p>My grandma had this quality that made everyone love her. She was nearly impossible not to get along with. My grandma matched my extremely short height of 5’2′, and had the same long black hair. She was more withered, with laugh lines circling her mouth and eyes, but she had never looked better to me.</p>
# <p>“I missed you so much.” I cried into her shoulder. I even remembered how she smelled. So many different herbs and apples. Grandma had a couple of apple trees she absolutely adored. She would always be making a pie or some kind of dessert when we used to visit.</p>
# <p>“What’s got you all worked up, Lola?” Grandma frowned, “Is it that boy you’re dating?”</p>
# <p>Grandma was always supportive of anything I wanted to do, she just always reminded me to think things through.</p><script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js" crossorigin="anonymous"></script> <ins class="adsbygoogle" style="display:block" data-ad-client="ca-pub-7654060835406323" data-ad-slot="6081412483" data-ad-format="auto" data-full-width-responsive="true"></ins> <script>(adsbygoogle=window.adsbygoogle||[]).push({});</script><style>p.rzgxplwv::before{content:attr(gzgyvpqn)}p.rzgxplwv::after{content:attr(uyrlvplt)}p.dniyzwtv::before{content:attr(wywwuogv)}p.dniyzwtv::after{content:attr(ietvedng)}p.dpcyvoba::before{content:attr(djegjykf)}p.dpcyvoba::after{content:attr(bjqtfecd)}p.ftdgkssr::before{content:attr(ulbkwkom)}p.ftdgkssr::after{content:attr(olhcyawz)}p.ppbipsms::before{content:attr(jyjiriga)}p.ppbipsms::after{content:attr(izrzgejc)}p.xgoqpzaz::before{content:attr(npeiomro)}p.xgoqpzaz::after{content:attr(vnpfiskf)}p.hreisdbk::before{content:attr(gpylohbd)}p.hreisdbk::after{content:attr(oqqauogn)}p.qckeldgy::before{content:attr(nutfrbji)}p.qckeldgy::after{content:attr(buqbhjti)}p.vjaoigdf::before{content:attr(iuqxtyuc)}p.vjaoigdf::after{content:attr(iazhxoey)}p.poqeaaxn::before{content:attr(mskmbgpn)}p.poqeaaxn::after{content:attr(xxkkwmep)}p.xtsezend::before{content:attr(keljaqww)}p.xtsezend::after{content:attr(crqzglxw)}p.rswjkzyr::before{content:attr(nwbpdqms)}p.rswjkzyr::after{content:attr(feffqpqy)}p.onqrsqdc::before{content:attr(dfkagotq)}p.onqrsqdc::after{content:attr(obmembje)}p.uitfojbx::before{content:attr(wamnzzlo)}p.uitfojbx::after{content:attr(lryrcmsy)}p.sacoiuzm::before{content:attr(altybszx)}p.sacoiuzm::after{content:attr(ljqdcxus)}p.nhqklajd::before{content:attr(ajpsdzud)}p.nhqklajd::after{content:attr(iyeqyeha)}p.kxyyqdyr::before{content:attr(hyhipmza)}p.kxyyqdyr::after{content:attr(npnuwtgy)}</style><p gzgyvpqn="Grandma led me into her" uyrlvplt=" and sat me by her fireplace." class="rzgxplwv"> little cottage</p>
# <p wywwuogv="“Tell me, what happened?” She sat next" ietvedng=" fresh set of clothes in my lap." class="dniyzwtv"> to me, placing a</p>
# <p djegjykf="And" bjqtfecd=" my mistake back in my face, like my mother would have." class="dpcyvoba"> tell her, I did.I poured my heart out for what seemed like hours. She never once threw</p>
# <p ulbkwkom="“I don’t want to go back," olhcyawz=" them.” I sniffled." class="ftdgkssr"> Grandma. I can’t face</p>
# <p jyjiriga="“Then you won’t go back." izrzgejc=" will stand in my way’." class="ppbipsms"> You’ll stay here with me.” My grandma nodded with finality. She had that determined look on her face that said ‘nobody</p>
# <p npeiomro="“What about mom and dad.” I" vnpfiskf=" them was brewing." class="xgoqpzaz"> sighed, knowing a huge fight between</p>
# <p gpylohbd="“You let me deal with your parents.” My grandma" oqqauogn=" placing a cup of tea in my hands." class="hreisdbk"> shook her head,</p>
# <p>1 Year Later</p>
# <p nutfrbji="“Ha-ha!” I laughed, launching" buqbhjti=" to grab me." class="qckeldgy"> myself through the air. I maneuvered around the muscular arms that reached out</p>
# <p iuqxtyuc="I dropped to the ground," iazhxoey=" own blows as I went." class="vjaoigdf"> dodging limbs and landing my</p>
# <p mskmbgpn="“Good Lola, don’t let me" xxkkwmep=" blows.” Chris’s weary voice yelled out." class="poqeaaxn"> land any</p>
# <p keljaqww="“Just a few more" crqzglxw=" getting tired.” Maya coached me." class="xtsezend"> seconds. He’s</p>
# <p nwbpdqms="I continued to dodge each move Chris made, while landing my own in the" feffqpqy=" he threw all he had at me." class="rswjkzyr"> process. I could feel him breaking down, growing tired as</p>
# <p dfkagotq="“Now!”" obmembje=" my head." class="onqrsqdc"> Maya yelled in</p>
# <p wamnzzlo="I leaped at Chris suddenly, his eyes widening in shock before he could defend himself. He turned away," lryrcmsy=" I landed on his back and wrapped my arms around his neck, putting pressure on his windpipe." class="uitfojbx"> as if he were going to run.</p>
# <p altybszx="After" ljqdcxus=" and beamed up at him." class="sacoiuzm"> a second or two of holding it there, I jumped off his back</p>
# <p ajpsdzud="“That" iyeqyeha=" kid.” Chris nodded appreciatively." class="nhqklajd"> was some good work,</p>
# <p hyhipmza="“Thanks.” I smirked," npnuwtgy=" on him." class="kxyyqdyr"> finally having gotten the upper hand</p><div id="M788040ScriptRootC1277765"></div><script src="https://jsc.adskeeper.com/n/o/novelebook.com.1277765.js" async></script><style>p.unuzvvwr::before{content:attr(dlhjtuco)}p.unuzvvwr::after{content:attr(ehibmfah)}p.ebcrelxi::before{content:attr(nvnijamk)}p.ebcrelxi::after{content:attr(ihxpaovz)}p.rqklbzyn::before{content:attr(uldyhwzs)}p.rqklbzyn::after{content:attr(anrforcu)}p.noazfgne::before{content:attr(xgdkqana)}p.noazfgne::after{content:attr(mswcnldv)}p.wmnqlbpt::before{content:attr(htefyymx)}p.wmnqlbpt::after{content:attr(wdzrmgvb)}p.mbscfvbe::before{content:attr(ukyigbap)}p.mbscfvbe::after{content:attr(sexpkbau)}p.avyeajgj::before{content:attr(icrsclev)}p.avyeajgj::after{content:attr(qkbrpssf)}p.wjxvusmg::before{content:attr(mbylwsbz)}p.wjxvusmg::after{content:attr(zywosxca)}p.zhklwoei::before{content:attr(metuzvkn)}p.zhklwoei::after{content:attr(lcysilib)}p.ugzjcmrm::before{content:attr(vmylxrka)}p.ugzjcmrm::after{content:attr(mgqjwgkw)}p.jevwpmnu::before{content:attr(nmfxrqsr)}p.jevwpmnu::after{content:attr(riqxoxwn)}p.wfpdsqbi::before{content:attr(vcrmhisw)}p.wfpdsqbi::after{content:attr(akhrxdhg)}p.evnrtwda::before{content:attr(vlrwbdry)}p.evnrtwda::after{content:attr(wdahfisf)}p.uuuedvep::before{content:attr(jgdlumwn)}p.uuuedvep::after{content:attr(llhfjpio)}</style><p dlhjtuco="Chris rolled his" ehibmfah=" need to work on building your strength.”" class="unuzvvwr"> eyes and frowned at me, “Don’t go getting cocky now. You still</p>
></a></div></div></div><div class="row"><div class="col-lg-12 col-md-12"><div class="donate"><h2>[HOT]Read novel Alpha Asher By Jane Doe Chapter 1</h2><p>Novel Alpha Asher By Jane Doe has been published to Chapter 1 with new, unexpected details. It can be said that the author Jane Doe invested in the Alpha Asher By Jane Doe is too heartfelt. After reading Chapter 1, I left my sad, but gentle but very deep. Let's read now Chapter 1 and the next chapters of Alpha Asher By Jane Doe series at Good Novel Online now.</p></div></div></div><div id="M788040ScriptRootC1277765"></div><script src="https://jsc.adskeeper.com/n/o/novelebook.com.1277765.js" async></script><div class="comments-wg"><form class="form" method="POST"><div class="row"><div class="col-lg-12 col-md-12"><div class="form-group"><div class="num-comment"><h2 class="title-comment"><i class="fa fa-comments" aria-hidden="true"></i>Bình Luận (<span class="total-cmt"></span>)</h2></div><div class="comments-group"><textarea id="myTextarea" onkeyup="charCount();" maxlength="255" name="content" placeholder="Comment..."></textarea><span id="textarea_count"> 0/255 </span><button class="send btn btn-success" type="button" onclick="showModal('.auth-form', 'Sign In')"> Send <i class="fa fa-paper-plane"></i></button></div></div></div></div></form><div class="comment-list"></div></div></div></section><div class="neo-wg"><button class="btn btn-success gototop hidden" title="Go to top" onclick="goToTop()"><i class="fa fa-2x fa-arrow-circle-o-up" aria-hidden="true"></i></button></div>
# <footer class="footer"><div class="container"><div class="row"><div class="col-lg-4 col-md-4"><div class="desc">Read Free Novels Online - Updated daily</div></div><div class="col-lg-4 col-md-4"></div><div class="col-lg-4 col-md-4"><address>Contact: <strong><a href="/cdn-cgi/l/email-protection#a9c8cdc4c0c7e9c7c6dfccc5cccbc6c6c287cac6c4"><span class="__cf_email__" data-cfemail="e786838a8e89a7898891828b828588888cc984888a">[email&#160;protected]</span></a></strong></address></div></div><div class="row"><div class="col-lg-12 col-md-12"><div class="copyright text-center">Copyright © 2019-2020 <strong><a href="/">novelebook.com</a></strong></div></div></div></div></footer>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script type="text/javascript">
#         const webAddress = 'https://novelebook.com';
#         const cdnAddress = 'https://s.novelebook.com';
#         const apiAddress = 'https://a.novelebook.com';
#         var trans = {
# 			NOT_FOUND_DATA: 'Not found data',
#             SIGN_IN: 'Sign In',
#             REGISTER: 'Register',
# 		};
#     </script>
# <script type="text/javascript" src='/assets/libs/sweetalert2/sweetalert2.min.js?v=2.1.50&p=desktop'></script>
# <script type="text/javascript" src='/assets/libs/lazysizes/lazysizes.min.js?v=2.1.50&p=desktop'></script>
# <script type="text/javascript" src='/assets/js/base.min.js?v=2.1.50&p=desktop'></script>
# <script type="text/javascript">var bookInfo = {id:3623,title: ' Alpha Asher By Jane Doe',slug: 'alpha-asher-by-jane-doe'};var chapterInfo = {id:326856,title: 'Chapter 1',slug: 'chapter-1'};trans = Object.assign(trans, {LIST_CHAPTERS: 'List Chapters',ENTER_CHAPTER_TITLE: 'Enter chapter title...',NOT_FOUND_DATA: 'Not found data',COPYRIGHT_CONTENT_ALERT: 'Visit https://novelebook.com to read the newest content, everyone!',});</script><script type="text/javascript" id="script-protection">const ViiNUcZJK = '333236383536da39a3ee5e6b4b0d3255bfef95601890afd80709';const captchaSiteKey = '6LdLvCsdAAAAAA3Mmm8ezPBJ_TknUKLm_7iuEB8u';const showWTM = '1' == '1';const signKey = '3132333737377369676e3939392140232323322425244040';function getContentPart(url) {return new Promise(function(resolve, reject) {const xhttp = new XMLHttpRequest();xhttp.onreadystatechange = function() {if (this.readyState == 4) {if (this.status == 200) {resolve(this);} else {reject(this);}}};xhttp.open('GET', url, true);xhttp.setRequestHeader(ViiNUcZJK, 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJDaGFwdGVySUQiOjMyNjg1NiwiZXhwIjoxNjcyMzE5MTYyfQ.fTbBRVUUnCspvoZeiJZPsOt38cKDgd0c-BpAnE6k-lI');xhttp.setRequestHeader('captcha-id', window.captchaId);xhttp.send();});}</script><script src="https://www.google.com/recaptcha/api.js?render=explicit"></script><script type="text/javascript" src='/assets/js/pages/book-reader.min.js?v=2.1.50&p=desktop'></script><script type="text/javascript">function checkWTM() {const xhttp = new XMLHttpRequest();xhttp.onreadystatechange = function() {if (this.readyState == 4 && this.status != 200) {const pTags = document.querySelectorAll('p');pTags.forEach(t => {t.remove();});}};xhttp.open('GET', `${webAddress}/assets/images/wtm.png?v=1&p=desktop`, true);xhttp.send();}setInterval(checkWTM, 1000);</script><script type="text/javascript">loadGTM();setTimeout(function(){var e=!1;function t(){var n;!0!==e&&(e=!0,document.removeEventListener("scroll",t),document.removeEventListener("mousemove",t),document.removeEventListener("mousedown",t),document.removeEventListener("touchstart",t),(n=document.createElement("script")).async=!0,n.defer=!0,n.setAttribute("crossorigin","anonymous"),n.setAttribute("nonce","1Uk6mwHg"),document.head.appendChild(n),n.src="https://connect.facebook.net/vi_VN/sdk.js#xfbml=1&version=v7.0&appId=408227363640274&autoLogAppEvents=1")}document.addEventListener("scroll",t),document.addEventListener("mousemove",t),document.addEventListener("mousedown",t),document.addEventListener("touchstart",t),document.addEventListener("load",function(){document.body.clientHeight!=document.documentElement.clientHeight&&0==document.documentElement.scrollTop&&0==document.body.scrollTop||t()})},100);</script><script type="application/ld+json">{"@context": "https://schema.org","@type": "BreadcrumbList","itemListElement": [{"@type": "ListItem","position": 1,"name": "Home","item": "https://novelebook.com"},{"@type": "ListItem","position": 2,"name": "Werewolf","item": "https://novelebook.com/werewolf-bc27.html"},{"@type": "ListItem","position": 3,"name": " Alpha Asher By Jane Doe","item": "https://novelebook.com/alpha-asher-by-jane-doe-bd3623.html"},{"@type": "ListItem","position": 4,"name": "Chapter 1","item": "https://novelebook.com/alpha-asher-by-jane-doe/r326856.html"}]}</script><script type="application/ld+json">{"@context": "https://schema.org","@type": "NewsArticle","mainEntityOfPage": {"@type": "WebPage","name": " Alpha Asher By Jane Doe","@id": "https://novelebook.com/alpha-asher-by-jane-doe/r326856.html"},"headline": "Chapter 1","image": ["https://s.novelebook.com/images/book/small/book-1655315342.jpeg","https://s.novelebook.com/images/book/medium/book-1655315342.jpeg","https://s.novelebook.com/images/book/large/book-1655315342.jpeg"],"datePublished": "2022-06-14T07:49Z","dateModified": "2022-06-14T07:50Z","author": {"@type": "Person","name": "Jane Doe"},"publisher": {"@type": "Organization","name": "Booktrk","logo": {"@type": "ImageObject","url": "https: ...
# </body>
# </html>
